# %% [markdown]
# # Laboratory Activity 2
#
# ###### _Python — CCQUAMET_

# %%
# 1. Import the same data
import pandas as pd

df = pd.read_excel("Module2_Excel_LabAct 1.xlsx", skiprows=2) # Skip title

# 2. Clean the .csv file
df.drop_duplicates()

# 3. Show the first 5 rows
df.head()
# Out:
#   Student ID  Gender Race/Ethnicity  Parental Education    Lunch Type  \
# 0       S001  female        group B   bachelor's degree      standard
# 1       S002  female        group C        some college      standard
# 2       S003  female        group B     master's degree      standard
# 3       S004    male        group A  associate's degree  free/reduced
# 4       S005    male        group C        some college      standard
#
#   Test Prep Course  Math Score  Reading Score  Writing Score
# 0             none          72             72             74
# 1        completed          69             90             88
# 2             none          90             95             93
# 3             none          47             57             44
# 4             none          76             78             75

# %%
# 4. Show datatypes of each column
print(df.dtypes)
# Out:
# Student ID              str
# Gender                  str
# Race/Ethnicity          str
# Parental Education      str
# Lunch Type              str
# Test Prep Course        str
# Math Score            int64
# Reading Score         int64
# Writing Score         int64
# dtype: object

# %%
# 5. Summarize the data and round it into two decimal places
df.describe().round(2)
# Out:
#        Math Score  Reading Score  Writing Score
# count       30.00          30.00          30.00
# mean        62.00          67.43          64.47
# std         16.84          16.28          16.65
# min         18.00          32.00          28.00
# 25%         50.75          55.50          52.75
# 50%         64.50          68.00          64.00
# 75%         71.75          80.25          74.75
# max         90.00          95.00          93.00
